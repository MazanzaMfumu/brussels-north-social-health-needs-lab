# %%
# Import 

from pathlib import Path

import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Définir les chemins

ROOT = Path.cwd()

if ROOT.name == "notebooks":
    ROOT = ROOT.parent

PROCESSED_DIR = ROOT / "data" / "processed"
FIGURES_DIR = ROOT / "outputs" / "figures"
MAPS_DIR = ROOT / "outputs" / "maps"

FIGURES_DIR.mkdir(
    parents=True,
    exist_ok=True
)

MAPS_DIR.mkdir(
    parents=True,
    exist_ok=True
)

print("Project root:", ROOT)
print("Figures directory:", FIGURES_DIR)
print("Maps directory:", MAPS_DIR)

# %%
# Chargement d'un nouveau GeoJSON

file_path = (
    PROCESSED_DIR
    / "brussels_monitoring_vulnerability.geojson"
)

gdf = gpd.read_file(
    file_path
)

print(
    "Shape:",
    gdf.shape
)

print(
    "CRS:",
    gdf.crs
)

gdf.head()
# Out:
# Shape: (145, 12)
# CRS: EPSG:4326
#    territory_code           territory territory_name_urbis_fr  \
# 0              83          Conscience              CONSCIENCE
# 1              80              Helmet                  HELMET
# 2              19  Vieux Laeken Ouest      VIEUX LAEKEN OUEST
# 3              20    Vieux Laeken Est        VIEUX LAEKEN EST
# 4             800      Industrie Nord          INDUSTRIE NORD
#
#   territory_name_urbis_nl territory_level  unemployment_rate  \
# 0              CONSCIENCE   neighbourhood              17.50
# 1                  HELMET   neighbourhood              19.52
# 2          OUD LAKEN WEST   neighbourhood              17.90
# 3          OUD LAKEN OOST   neighbourhood              21.51
# 4         INDUSTRIE NOORD   neighbourhood               4.99
#
#    unemployment_year  cpas_rate  cpas_year  bim_rate  bim_year  \
# 0               2023       7.63       2023     29.45      2024
# 1               2023       8.52       2023     35.66      2024
# 2               2023       7.00       2023     38.30      2024
# 3               2023       7.10       2023     42.48      2024
# 4               2023        NaN       2023       NaN      2024
#
#                                             geometry
# 0  POLYGON ((4.39484 50.87157, 4.39527 50.87168, ...
# 1  POLYGON ((4.37962 50.87244, 4.3802 50.87259, 4...
# 2  POLYGON ((4.33832 50.87641, 4.33844 50.87643, ...
# 3  POLYGON ((4.34222 50.87138, 4.34222 50.87138, ...
# 4  POLYGON ((4.38459 50.90379, 4.3846 50.9038, 4....

# %%
# Carte de contrôle des quartiers du Monitoring

ax = gdf.plot(
    figsize=(10, 10),
    edgecolor="black",
    linewidth=0.3
)

ax.set_title(
    "Monitoring neighbourhoods – Brussels-Capital Region"
)

ax.axis("off")

plt.tight_layout()

plt.savefig(
    MAPS_DIR
    / "monitoring_neighbourhoods_control_map.png",
    dpi=200,
    bbox_inches="tight"
)

plt.show()

# %%
# Première carte analytique : chômage (2023)

ax = gdf.plot(
    column="unemployment_rate",
    legend=True,
    figsize=(10, 10),
    edgecolor="black",
    linewidth=0.2
)

ax.set_title(
    "Unemployment rate by Monitoring neighbourhood – 2023"
)

ax.axis("off")

plt.tight_layout()

plt.savefig(
    MAPS_DIR
    / "monitoring_unemployment_2023_map.png",
    dpi=200,
    bbox_inches="tight"
)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 20
#      16
#      17 plt.tight_layout()
#      18
#      19 plt.savefig(
# ---> 20     MAPS_DIR
#      21     / "monitoring_unemployment_2023_map.png",
#      22     dpi=200,
#      23     bbox_inches="tight"
#
# NameError: name 'MAPS_DIR' is not defined

# %%
# Première carte analytique : cpas (2023)

ax = gdf.plot(
    column="cpas_rate",
    legend=True,
    figsize=(10, 10),
    edgecolor="black",
    linewidth=0.2
)

ax.set_title(
    "CPAS/RIS beneficiary rate by Monitoring neighbourhood – 2023"
)

ax.axis("off")

plt.tight_layout()

plt.savefig(
    MAPS_DIR
    / "monitoring_cpas_2023_map.png",
    dpi=200,
    bbox_inches="tight"
)

plt.show()

# %%
# # Première carte analytique : bim (2024)

ax = gdf.plot(
    column="bim_rate",
    legend=True,
    figsize=(10, 10),
    edgecolor="black",
    linewidth=0.2
)

ax.set_title(
    "BIM beneficiary rate by Monitoring neighbourhood – 2024"
)

ax.axis("off")

plt.tight_layout()

plt.savefig(
    MAPS_DIR
    / "monitoring_bim_2024_map.png",
    dpi=200,
    bbox_inches="tight"
)

plt.show()
